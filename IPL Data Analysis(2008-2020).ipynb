# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\abishek\\excel sheets\\IPL Matches 2008-2020.csv")

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# ### column method has many null values
# null values in method are normal matches

# %%
df['method'].fillna(value='Nomral',inplace=True)

# %% [markdown]
# ## Lets create a seperate Data Frame for D/N method matches

# %%
dlsdf=df[df['method']=='D/L']
dlsdf
# Out:
#           id           city        date   player_of_match  \
# 40    336022          Delhi  2008-05-17  DPMD Jayawardene
# 43    336025        Kolkata  2008-05-18           M Ntini
# 60    392183      Cape Town  2009-04-19        DL Vettori
# 63    392186         Durban  2009-04-21          CH Gayle
# 89    392214      Centurion  2009-05-07         ML Hayden
# 192   501215          Kochi  2011-04-18       BB McCullum
# 221   501245        Kolkata  2011-05-07     Iqbal Abdulla
# 231   501255      Bangalore  2011-05-14          CH Gayle
# 429   733993          Delhi  2014-05-10          DW Steyn
# 477   829743  Visakhapatnam  2015-04-22         DA Warner
# 508   829807      Hyderabad  2015-05-15           V Kohli
# 538   980943      Hyderabad  2016-04-26          AB Dinda
# 561   980989        Kolkata  2016-05-14         YK Pathan
# 565   980997  Visakhapatnam  2016-05-17          AB Dinda
# 566   980999      Bangalore  2016-05-18           V Kohli
# ...

# %% [markdown]
# ===============================================================================================================================
# ## Lets see most wins by a team for total data frame

# %%
temp=pd.DataFrame({"Winner":df['winner']})
count_wins=temp.value_counts()
labels=[X[0] for X in count_wins.keys()]
plt.subplots(figsize=(20,12))
plt.pie(x=count_wins,autopct="%.1f%%",labels=labels)
plt.title("Most wins in IPL",fontsize=17)
plt.show()

# %% [markdown]
# ### Lets see the same for D/L method matches

# %%
teamsd=pd.DataFrame({'Winner':dlsdf['winner']})
countwins=teamsd.value_counts()
labels1=[X[0] for X in countwins.keys()]
plt.subplots(figsize=(20,12))

plt.pie(x=countwins,autopct="%.1f%%",labels=labels1)
plt.title("Most wins in D/L method")
# Out:
# Text(0.5, 1.0, 'Most wins in D/L method')

# %% [markdown]
# ===============================================================================================================================
# ## Most wins in eleminator

# %% [markdown]
# ### Lets create a seperate Data Frame for eliminator

# %%
eldf=df[df['eliminator']=='Y']
eldf
# Out:
#           id       city        date player_of_match  \
# 66    392190  Cape Town  2009-04-23       YK Pathan
# 130   419121    Chennai  2010-03-21        J Theron
# 328   598004  Hyderabad  2013-04-07       GH Vihari
# 341   598017  Bangalore  2013-04-16         V Kohli
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner
# 476   829741  Ahmedabad  2015-04-21        SE Marsh
# 610  1082625     Rajkot  2017-04-29       KH Pandya
# 705  1175365      Delhi  2019-03-30         PP Shaw
# 746  1178426     Mumbai  2019-05-02       JJ Bumrah
# 757  1216493      Dubai  2020-09-20      MP Stoinis
# 776  1216512  Abu Dhabi  2020-10-18     LH Ferguson
# 781  1216517      Dubai  2020-10-18        KL Rahul
# 811  1216547      Dubai  2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 66                                    Newlands              1
# 130            MA Chidambaram Stadium, Chepauk              0
# ...

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(eldf['winner']) 
plt.title('Eliminator Wins',fontsize=17)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\hi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ===============================================================================================================================
# ## Toss Decision

# %%
teams=df['toss_winner'].unique()
decision_making=pd.DataFrame([],columns=['Toss Winner','Decision','Times'])
for id, element in enumerate(teams):
    temp_bat=df[(df['toss_winner']== element)&(df['toss_decision']=='bat')]
    temp_field=df[(df['toss_winner']==element)&(df['toss_decision']=='field')]
    decision_making=decision_making.append({'Toss Winner':element,'Decision':'bat'
                                           ,'Times':temp_bat['toss_winner'].count()}, ignore_index=True)
    decision_making=decision_making.append({'Toss Winner':element,'Decision':'field'
                                           ,'Times':temp_field['toss_winner'].count()}, ignore_index=True)

# %%
sns.catplot(x='Toss Winner',y ='Times', hue='Decision', data=decision_making, kind='bar', height=5, aspect=2)
plt.xticks(rotation=90)
plt.title('Toss Decision')
plt.xlabel('Teams')
plt.show()

# %% [markdown]
# ===============================================================================================================================
# ## Lets analyze venues

# %% [markdown]
# ### 1st lets see all matches

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.barplot(x=df['venue'].value_counts().head(10).index,
           y=df['venue'].value_counts().head(10).values,
           )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Lets see matches played by D/L method

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.barplot(x=dlsdf['venue'].value_counts().head(10).index,
           y=dlsdf['venue'].value_counts().head(10).values,
           )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### The top in the above list might have bad weather conditions frequently

# %% [markdown]
# ===============================================================================================================================
# ## Lets analyze Player of the macth in each data sets

# %% [markdown]
# ### Normal Matches

# %%
sns.set(rc={'figure.figsize':(12,16)})
sns.barplot(x=df['player_of_match'].value_counts().head(20).values,
            y=df['player_of_match'].value_counts().head(20).index)
plt.title('Player Of the match',fontsize=23)
plt.show()

# %% [markdown]
# ### Matches played by D/L method

# %%
teamsd=pd.DataFrame({'Winner':dlsdf['player_of_match']})
countwins=teamsd.value_counts()
labels1=[X[0] for X in countwins.keys()]
plt.subplots(figsize=(20,12))

plt.pie(x=countwins,autopct="%.1f%%",labels=labels1)
plt.title("Player of the match  in D/L method")
# Out:
# Text(0.5, 1.0, 'Player of the match  in D/L method')

# %% [markdown]
# ### Eliminator Matches

# %%
teamsd=pd.DataFrame({'Winner':eldf['player_of_match']})
countwins=teamsd.value_counts()
labels1=[X[0] for X in countwins.keys()]
plt.subplots(figsize=(20,12))

plt.pie(x=countwins,autopct="%.1f%%",labels=labels1)
plt.title("Player of the match  in D/L method")
# Out:
# Text(0.5, 1.0, 'Player of the match  in D/L method')

# %% [markdown]
# ### May be each eliminator matches have different winners
